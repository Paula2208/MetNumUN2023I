# %% [markdown]
# <a href="https://colab.research.google.com/github/Paula2208/MetNumUN2023I/blob/master/Lab3/pguzmanz_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Applied Data Science with Python**

# %% [markdown]
# ## Linkedin Certifications Post

# %% [markdown]
# [https://www.linkedin.com/in/paula-guzman-2208/](https://www.linkedin.com/in/paula-guzman-2208/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Courses Certifications

# %% [markdown]
# ### [Python for Data Science](https://cognitiveclass.ai/courses/python-for-data-science)

# %% [markdown]
# ![certificate_1.png](data:image/png;base64,...)

# %% [markdown]
# Authenticity of this certificate can be validated by going to:
# https://courses.cognitiveclass.ai/certificates/9ab2c5379a0d45ad9519f37cee4f3205

# %% [markdown]
# ### [Data Analysis with Python](https://cognitiveclass.ai/courses/data-analysis-python)

# %% [markdown]
# ![certificate_2.png](data:image/png;base64,...)

# %% [markdown]
# Authenticity of this certificate can be validated by going to:
#
# [https://courses.cognitiveclass.ai/certificates/400affe30cf74a3584ffb8b544eb05d0](https://courses.cognitiveclass.ai/certificates/400affe30cf74a3584ffb8b544eb05d0)

# %% [markdown]
# ### [Data Visualization with Python](https://cognitiveclass.ai/courses/data-visualization-python)

# %% [markdown]
# ![certificate_3.png](data:image/png;base64,...)

# %% [markdown]
# Authenticity of this certificate can be validated by going to:
#
# [https://courses.cognitiveclass.ai/certificates/f9d31547882e47ff93d2a4c6096b1746](https://courses.cognitiveclass.ai/certificates/f9d31547882e47ff93d2a4c6096b1746)
