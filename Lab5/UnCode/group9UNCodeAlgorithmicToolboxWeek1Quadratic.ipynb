# %% [markdown]
# <a href="https://colab.research.google.com/github/Paula2208/MetNumUN2023I/blob/master/Lab5/UnCode/group9UNCodeAlgorithmicToolboxWeek1Quadratic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **UNCODE SUBMISSION**
#
# Paula Daniela Guzmán Zabala

# %%
import math 
def solve_quad(b, c):
  """Solve a quadratic equation, x**2 + bx + c = 0.
    
    Parameters
    ----------
    b, c : float
       Coefficients
       
    Returns
    -------
    x1, x2 : float or complex roots.  """
    
  # ... enter your code here ...
  raiz = b**2 - (4*c)
  if raiz == b**2:
    x1 = -b
    x2 = -(c/b)
  elif raiz >= 0:
    x1 = (-b + math.sqrt(raiz))/2
    x2 = (-b - math.sqrt(raiz))/2
  else:
    x1 = complex( -b/2, math.sqrt(-raiz)/2)
    x2 = complex( -b/2, -math.sqrt(-raiz)/2)
  
  return x1,x2

# %%
import cmath

def solve_quad_Po_Shen_Loh(b, c):

   """Solve a quadratic equation, x**2 + bx + c = 0.
    
    Parameters
    ----------
    b, c : float
       Coefficients
       
    Returns
    -------
    u : The distance from b/2 to x and x2  and -1  if floting-point limitations
    x1, x2 : float or complex roots.  """
    
   # ... enter your code here ...
   if(b/2)**2 - c == (b/2)**2:
     u = -1
     x1 = -b
     x2 = -c/b
   else:
     u = cmath.sqrt( (b/2)**2 - c)
     x1 = -((b/2) - u)
     x2 = -((b/2) + u)
   #print(x1," --- ",x2," --- u: ",u)
   return u, x1, x2

# %% [markdown]
# **UNCode Submission**

# %% [markdown]
# ![Screenshot 2023-04-17 at 8.49.13 PM.png](data:image/png;base64,...)
